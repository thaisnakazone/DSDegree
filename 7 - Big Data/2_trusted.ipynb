# %% [markdown]
# # Criando um Data Lake

# %% [markdown]
# ## 2. Tratamento dos dados na camada "trusted"
# Os dados que estão na camada "raw" deverão ser tratados antes de serem salvos no formato "parquet".

# %% [markdown]
# ### 2.1 Configuração

# %%
username = 'thais'

northwind = f'/letscode/{username}/northwind/'

spark.sql(f'CREATE DATABASE IF NOT EXISTS letscode_{username}_trusted')
spark.sql(f'USE letscode_{username}_trusted')
# Out:
# Out[365]: DataFrame[]

# %% [markdown]
# ### 2.2 Carregando os dados
# Criando um dicionário para armazenar um DataFrame do Spark para cada tabela CSV carregada.

# %%
dict_df_northwind = dict()
path_raw = northwind + 'raw/'
for folder in dbutils.fs.ls(path_raw):
    for file in dbutils.fs.ls(path_raw + folder.name):
        file_without_extension = f'{file.name}'.rsplit('.', 1)[0]
        dict_df_northwind[file_without_extension] = spark.read.csv(path_raw + folder.name + file.name, header=True, inferSchema=True)

# %% [markdown]
# ### 2.3 Exploração dos dados
# Como o objetivo do projeto não é analisar os dados, farei uma verificação simples em cada tabela, apenas para observar se o tipo dos dados está correto, se há dados nulos ou duplicados.

# %% [markdown]
# #### 2.3.1 Tabela "categories"

# %%
dict_df_northwind['categories'].toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category_id</th>
#       <th>category_name</th>
#       <th>description</th>
#       <th>picture</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Beverages</td>
#       <td>Soft drinks, coffees, teas, beers, and ales</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Condiments</td>
#       <td>Sweet and savory sauces, relishes, spreads, an...</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Confections</td>
#       <td>Desserts, candies, and sweet breads</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Dairy Products</td>
#       <td>Cheeses</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Grains/Cereals</td>
#       <td>Breads, crackers, pasta, and cereal</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Meat/Poultry</td>
#       <td>Prepared meats</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Produce</td>
#       <td>Dried fruit and bean curd</td>
#       <td>binary data</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Seafood</td>
#       <td>Seaweed and fish</td>
#       <td>binary data</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['categories'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    8 non-null      int32
#  1   category_name  8 non-null      object
#  2   description    8 non-null      object
#  3   picture        8 non-null      object
# dtypes: int32(1), object(3)
# memory usage: 352.0+ bytes

# %%
dict_df_northwind['categories'].toPandas().duplicated().sum()
# Out:
# Out[369]: 0

# %% [markdown]
# #### 2.3.2 Tabela "customers"

# %%
dict_df_northwind['customers'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>company_name</th>
#       <th>contact_name</th>
#       <th>contact_title</th>
#       <th>address</th>
#       <th>city</th>
#       <th>region</th>
#       <th>postal_code</th>
#       <th>country</th>
#       <th>phone</th>
#       <th>fax</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ALFKI</td>
#       <td>Alfreds Futterkiste</td>
#       <td>Maria Anders</td>
#       <td>Sales Representative</td>
#       <td>Obere Str. 57</td>
#       <td>Berlin</td>
#       <td>NULL</td>
#       <td>12209</td>
#       <td>Germany</td>
#       <td>030-0074321</td>
#       <td>030-0076545</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ANATR</td>
#       <td>Ana Trujillo Emparedados y helados</td>
#       <td>Ana Trujillo</td>
#       <td>Owner</td>
#       <td>Avda. de la Constitución 2222</td>
#       <td>México D.F.</td>
#       <td>NULL</td>
#       <td>05021</td>
#       <td>Mexico</td>
#       <td>(5) 555-4729</td>
#       <td>(5) 555-3745</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ANTON</td>
#       <td>Antonio Moreno Taquería</td>
#       <td>Antonio Moreno</td>
#       <td>Owner</td>
#       <td>Mataderos  2312</td>
#       <td>México D.F.</td>
#       <td>NULL</td>
#       <td>05023</td>
#       <td>Mexico</td>
#       <td>(5) 555-3932</td>
#       <td>NULL</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AROUT</td>
#       <td>Around the Horn</td>
#       <td>Thomas Hardy</td>
#       <td>Sales Representative</td>
#       <td>120 Hanover Sq.</td>
#       <td>London</td>
#       <td>NULL</td>
#       <td>WA1 1DP</td>
#       <td>UK</td>
#       <td>(171) 555-7788</td>
#       <td>(171) 555-6750</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BERGS</td>
#       <td>Berglunds snabbköp</td>
#       <td>Christina Berglund</td>
#       <td>Order Administrator</td>
#       <td>Berguvsvägen  8</td>
#       <td>Luleå</td>
#       <td>NULL</td>
#       <td>S-958 22</td>
#       <td>Sweden</td>
#       <td>0921-12 34 65</td>
#       <td>0921-12 34 67</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Percebe-se acima que existem dados nulos em "region", mas, nas informações abaixo não há registro de dados faltantes.
# Como esse fato não impactaria muito no objetivo do projeto de Big Data, não farei o tratamento dos dados nulos.

dict_df_northwind['customers'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    91 non-null     object
#  1   company_name   91 non-null     object
#  2   contact_name   91 non-null     object
#  3   contact_title  91 non-null     object
#  4   address        91 non-null     object
#  5   city           91 non-null     object
#  6   region         91 non-null     object
#  7   postal_code    91 non-null     object
#  8   country        91 non-null     object
#  9   phone          91 non-null     object
#  10  fax            91 non-null     object
# dtypes: object(11)
# memory usage: 7.9+ KB

# %%
dict_df_northwind['customers'].toPandas().duplicated().sum()
# Out:
# Out[372]: 0

# %% [markdown]
# #### 2.3.3 Tabela "employee_territories"

# %%
dict_df_northwind['employee_territories'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee_id</th>
#       <th>territory_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>6897</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>19713</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1581</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>1730</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>1833</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['employee_territories'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   employee_id   49 non-null     int32
#  1   territory_id  49 non-null     int32
# dtypes: int32(2)
# memory usage: 520.0 bytes

# %%
dict_df_northwind['employee_territories'].toPandas().duplicated().sum()
# Out:
# Out[375]: 0

# %% [markdown]
# #### 2.3.4 Tabela "employees"

# %%
dict_df_northwind['employees'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>employee_id</th>
#       <th>last_name</th>
#       <th>first_name</th>
#       <th>title</th>
#       <th>title_of_courtesy</th>
#       <th>birth_date</th>
#       <th>hire_date</th>
#       <th>address</th>
#       <th>city</th>
#       <th>region</th>
#       <th>postal_code</th>
#       <th>country</th>
#       <th>home_phone</th>
#       <th>extension</th>
#       <th>photo</th>
#       <th>notes</th>
#       <th>reports_to</th>
#       <th>photo_path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Davolio</td>
#       <td>Nancy</td>
#       <td>Sales Representative</td>
#       <td>Ms.</td>
#       <td>1948-12-08</td>
#       <td>1992-05-01</td>
#       <td>507 - 20th Ave. E.\nApt. 2A</td>
#       <td>Seattle</td>
#       <td>WA</td>
#       <td>98122</td>
#       <td>USA</td>
#       <td>(206) 555-9857</td>
#       <td>5467</td>
#       <td>binary data</td>
#       <td>Education includes a BA in psychology from Col...</td>
#       <td>2</td>
#       <td>http://accweb/emmployees/davolio.bmp</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Fuller</td>
#       <td>Andrew</td>
#       <td>Vice President, Sales</td>
#       <td>Dr.</td>
#       <td>1952-02-19</td>
#       <td>1992-08-14</td>
#       <td>908 W. Capital Way</td>
#       <td>Tacoma</td>
#       <td>WA</td>
#       <td>98401</td>
#       <td>USA</td>
#       <td>(206) 555-9482</td>
#       <td>3457</td>
#       <td>binary data</td>
#       <td>Andrew received his BTS commercial in 1974 and...</td>
#       <td>NULL</td>
#       <td>http://accweb/emmployees/fuller.bmp</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Leverling</td>
#       <td>Janet</td>
#       <td>Sales Representative</td>
#       <td>Ms.</td>
#       <td>1963-08-30</td>
#       <td>1992-04-01</td>
#       <td>722 Moss Bay Blvd.</td>
#       <td>Kirkland</td>
#       <td>WA</td>
#       <td>98033</td>
#       <td>USA</td>
#       <td>(206) 555-3412</td>
#       <td>3355</td>
#       <td>binary data</td>
#       <td>Janet has a BS degree in chemistry from Boston...</td>
#       <td>2</td>
#       <td>http://accweb/emmployees/leverling.bmp</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Peacock</td>
#       <td>Margaret</td>
#       <td>Sales Representative</td>
#       <td>Mrs.</td>
#       <td>1937-09-19</td>
#       <td>1993-05-03</td>
#       <td>4110 Old Redmond Rd.</td>
#       <td>Redmond</td>
#       <td>WA</td>
#       <td>98052</td>
#       <td>USA</td>
#       <td>(206) 555-8122</td>
#       <td>5176</td>
#       <td>binary data</td>
#       <td>Margaret holds a BA in English literature from...</td>
#       <td>2</td>
#       <td>http://accweb/emmployees/peacock.bmp</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Buchanan</td>
#       <td>Steven</td>
#       <td>Sales Manager</td>
#       <td>Mr.</td>
#       <td>1955-03-04</td>
#       <td>1993-10-17</td>
#       <td>14 Garrett Hill</td>
#       <td>London</td>
#       <td>NULL</td>
#       <td>SW1 8JR</td>
#       <td>UK</td>
#       <td>(71) 555-4848</td>
#       <td>3453</td>
#       <td>binary data</td>
#       <td>Steven Buchanan graduated from St. Andrews Uni...</td>
#       <td>2</td>
#       <td>http://accweb/emmployees/buchanan.bmp</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['employees'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        9 non-null      int32
#  1   last_name          9 non-null      object
#  2   first_name         9 non-null      object
#  3   title              9 non-null      object
#  4   title_of_courtesy  9 non-null      object
#  5   birth_date         9 non-null      datetime64[ns]
#  6   hire_date          9 non-null      datetime64[ns]
#  7   address            9 non-null      object
#  8   city               9 non-null      object
#  9   region             9 non-null      object
#  10  postal_code        9 non-null      object
#  11  country            9 non-null      object
#  12  home_phone         9 non-null      object
#  13  extension          9 non-null      int32
#  14  photo              9 non-null      object
#  15  notes              9 non-null      object
#  16  reports_to         9 non-null      object
#  17  photo_path         9 non-null      object
# dtypes: datetime64[ns](2), int32(2), object(14)
# memory usage: 1.3+ KB

# %%
dict_df_northwind['employees'].toPandas().duplicated().sum()
# Out:
# Out[378]: 0

# %% [markdown]
# #### 2.3.5 Tabela "order_details"

# %%
dict_df_northwind['order_details'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>product_id</th>
#       <th>unit_price</th>
#       <th>quantity</th>
#       <th>discount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10248</td>
#       <td>11</td>
#       <td>14.0</td>
#       <td>12</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10248</td>
#       <td>42</td>
#       <td>9.8</td>
#       <td>10</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10248</td>
#       <td>72</td>
#       <td>34.8</td>
#       <td>5</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10249</td>
#       <td>14</td>
#       <td>18.6</td>
#       <td>9</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10249</td>
#       <td>51</td>
#       <td>42.4</td>
#       <td>40</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['order_details'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2155 entries, 0 to 2154
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    2155 non-null   int32
#  1   product_id  2155 non-null   int32
#  2   unit_price  2155 non-null   float64
#  3   quantity    2155 non-null   int32
#  4   discount    2155 non-null   float64
# dtypes: float64(2), int32(3)
# memory usage: 59.1 KB

# %%
dict_df_northwind['order_details'].toPandas().duplicated().sum()
# Out:
# Out[381]: 0

# %% [markdown]
# #### 2.3.6 Tabela "orders"

# %%
dict_df_northwind['orders'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>employee_id</th>
#       <th>order_date</th>
#       <th>required_date</th>
#       <th>shipped_date</th>
#       <th>ship_via</th>
#       <th>freight</th>
#       <th>ship_name</th>
#       <th>ship_address</th>
#       <th>ship_city</th>
#       <th>ship_region</th>
#       <th>ship_postal_code</th>
#       <th>ship_country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10248</td>
#       <td>VINET</td>
#       <td>5</td>
#       <td>1996-07-04</td>
#       <td>1996-08-01</td>
#       <td>1996-07-16</td>
#       <td>3</td>
#       <td>32.38</td>
#       <td>Vins et alcools Chevalier</td>
#       <td>59 rue de l'Abbaye</td>
#       <td>Reims</td>
#       <td>NULL</td>
#       <td>51100</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10249</td>
#       <td>TOMSP</td>
#       <td>6</td>
#       <td>1996-07-05</td>
#       <td>1996-08-16</td>
#       <td>1996-07-10</td>
#       <td>1</td>
#       <td>11.61</td>
#       <td>Toms Spezialitäten</td>
#       <td>Luisenstr. 48</td>
#       <td>Münster</td>
#       <td>NULL</td>
#       <td>44087</td>
#       <td>Germany</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10250</td>
#       <td>HANAR</td>
#       <td>4</td>
#       <td>1996-07-08</td>
#       <td>1996-08-05</td>
#       <td>1996-07-12</td>
#       <td>2</td>
#       <td>65.83</td>
#       <td>Hanari Carnes</td>
#       <td>Rua do Paço, 67</td>
#       <td>Rio de Janeiro</td>
#       <td>RJ</td>
#       <td>05454-876</td>
#       <td>Brazil</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10251</td>
#       <td>VICTE</td>
#       <td>3</td>
#       <td>1996-07-08</td>
#       <td>1996-08-05</td>
#       <td>1996-07-15</td>
#       <td>1</td>
#       <td>41.34</td>
#       <td>Victuailles en stock</td>
#       <td>2, rue du Commerce</td>
#       <td>Lyon</td>
#       <td>NULL</td>
#       <td>69004</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10252</td>
#       <td>SUPRD</td>
#       <td>4</td>
#       <td>1996-07-09</td>
#       <td>1996-08-06</td>
#       <td>1996-07-11</td>
#       <td>2</td>
#       <td>51.30</td>
#       <td>Suprêmes délices</td>
#       <td>Boulevard Tirou, 255</td>
#       <td>Charleroi</td>
#       <td>NULL</td>
#       <td>B-6000</td>
#       <td>Belgium</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['orders'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          830 non-null    int32
#  1   customer_id       830 non-null    object
#  2   employee_id       830 non-null    int32
#  3   order_date        830 non-null    datetime64[ns]
#  4   required_date     830 non-null    datetime64[ns]
#  5   shipped_date      830 non-null    object
#  6   ship_via          830 non-null    int32
#  7   freight           830 non-null    float64
#  8   ship_name         830 non-null    object
#  9   ship_address      830 non-null    object
#  10  ship_city         830 non-null    object
#  11  ship_region       830 non-null    object
#  12  ship_postal_code  830 non-null    object
#  13  ship_country      830 non-null    object
# dtypes: datetime64[ns](2), float64(1), int32(3), object(8)
# memory usage: 81.2+ KB

# %%
dict_df_northwind['orders'].toPandas().duplicated().sum()
# Out:
# Out[384]: 0

# %% [markdown]
# #### 2.3.7 Tabela "products"

# %%
dict_df_northwind['products'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>product_name</th>
#       <th>supplier_id</th>
#       <th>category_id</th>
#       <th>quantity_per_unit</th>
#       <th>unit_price</th>
#       <th>units_in_stock</th>
#       <th>units_on_order</th>
#       <th>reorder_level</th>
#       <th>discontinued</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Chai</td>
#       <td>8</td>
#       <td>1</td>
#       <td>10 boxes x 30 bags</td>
#       <td>18.00</td>
#       <td>39</td>
#       <td>0</td>
#       <td>10</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Chang</td>
#       <td>1</td>
#       <td>1</td>
#       <td>24 - 12 oz bottles</td>
#       <td>19.00</td>
#       <td>17</td>
#       <td>40</td>
#       <td>25</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Aniseed Syrup</td>
#       <td>1</td>
#       <td>2</td>
#       <td>12 - 550 ml bottles</td>
#       <td>10.00</td>
#       <td>13</td>
#       <td>70</td>
#       <td>25</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Chef Anton's Cajun Seasoning</td>
#       <td>2</td>
#       <td>2</td>
#       <td>48 - 6 oz jars</td>
#       <td>22.00</td>
#       <td>53</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Chef Anton's Gumbo Mix</td>
#       <td>2</td>
#       <td>2</td>
#       <td>36 boxes</td>
#       <td>21.35</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['products'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         77 non-null     int32
#  1   product_name       77 non-null     object
#  2   supplier_id        77 non-null     int32
#  3   category_id        77 non-null     int32
#  4   quantity_per_unit  77 non-null     object
#  5   unit_price         77 non-null     float64
#  6   units_in_stock     77 non-null     int32
#  7   units_on_order     77 non-null     int32
#  8   reorder_level      77 non-null     int32
#  9   discontinued       77 non-null     int32
# dtypes: float64(1), int32(7), object(2)
# memory usage: 4.0+ KB

# %%
dict_df_northwind['products'].toPandas().duplicated().sum()
# Out:
# Out[387]: 0

# %% [markdown]
# #### 2.3.8 Tabela "region"

# %%
dict_df_northwind['region'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region_id</th>
#       <th>region_description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Eastern</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Western</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Northern</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Southern</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['region'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   region_id           4 non-null      int32
#  1   region_description  4 non-null      object
# dtypes: int32(1), object(1)
# memory usage: 176.0+ bytes

# %%
dict_df_northwind['region'].toPandas().duplicated().sum()
# Out:
# Out[390]: 0

# %% [markdown]
# #### 2.3.9 Tabela "shippers"

# %%
dict_df_northwind['shippers'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>shipper_id</th>
#       <th>company_name</th>
#       <th>phone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Speedy Express</td>
#       <td>(503) 555-9831</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>United Package</td>
#       <td>(503) 555-3199</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Federal Shipping</td>
#       <td>(503) 555-9931</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Alliance Shippers</td>
#       <td>1-800-222-0451</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>UPS</td>
#       <td>1-800-782-7892</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['shippers'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   shipper_id    6 non-null      int32
#  1   company_name  6 non-null      object
#  2   phone         6 non-null      object
# dtypes: int32(1), object(2)
# memory usage: 248.0+ bytes

# %%
dict_df_northwind['shippers'].toPandas().duplicated().sum()
# Out:
# Out[393]: 0

# %% [markdown]
# #### 2.3.10 Tabela "suppliers"

# %%
dict_df_northwind['suppliers'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>supplier_id</th>
#       <th>company_name</th>
#       <th>contact_name</th>
#       <th>contact_title</th>
#       <th>address</th>
#       <th>city</th>
#       <th>region</th>
#       <th>postal_code</th>
#       <th>country</th>
#       <th>phone</th>
#       <th>fax</th>
#       <th>homepage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Exotic Liquids</td>
#       <td>Charlotte Cooper</td>
#       <td>Purchasing Manager</td>
#       <td>49 Gilbert St.</td>
#       <td>London</td>
#       <td>NULL</td>
#       <td>EC1 4SD</td>
#       <td>UK</td>
#       <td>(171) 555-2222</td>
#       <td>NULL</td>
#       <td>NULL</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>New Orleans Cajun Delights</td>
#       <td>Shelley Burke</td>
#       <td>Order Administrator</td>
#       <td>P.O. Box 78934</td>
#       <td>New Orleans</td>
#       <td>LA</td>
#       <td>70117</td>
#       <td>USA</td>
#       <td>(100) 555-4822</td>
#       <td>NULL</td>
#       <td>#CAJUN.HTM#</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Grandma Kelly's Homestead</td>
#       <td>Regina Murphy</td>
#       <td>Sales Representative</td>
#       <td>707 Oxford Rd.</td>
#       <td>Ann Arbor</td>
#       <td>MI</td>
#       <td>48104</td>
#       <td>USA</td>
#       <td>(313) 555-5735</td>
#       <td>(313) 555-3349</td>
#       <td>NULL</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Tokyo Traders</td>
#       <td>Yoshi Nagase</td>
#       <td>Marketing Manager</td>
#       <td>9-8 Sekimai Musashino-shi</td>
#       <td>Tokyo</td>
#       <td>NULL</td>
#       <td>100</td>
#       <td>Japan</td>
#       <td>(03) 3555-5011</td>
#       <td>NULL</td>
#       <td>NULL</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Cooperativa de Quesos 'Las Cabras'</td>
#       <td>Antonio del Valle Saavedra</td>
#       <td>Export Administrator</td>
#       <td>Calle del Rosal 4</td>
#       <td>Oviedo</td>
#       <td>Asturias</td>
#       <td>33007</td>
#       <td>Spain</td>
#       <td>(98) 598 76 54</td>
#       <td>NULL</td>
#       <td>NULL</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['suppliers'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   supplier_id    29 non-null     int32
#  1   company_name   29 non-null     object
#  2   contact_name   29 non-null     object
#  3   contact_title  29 non-null     object
#  4   address        29 non-null     object
#  5   city           29 non-null     object
#  6   region         29 non-null     object
#  7   postal_code    29 non-null     object
#  8   country        29 non-null     object
#  9   phone          29 non-null     object
#  10  fax            29 non-null     object
#  11  homepage       29 non-null     object
# dtypes: int32(1), object(11)
# memory usage: 2.7+ KB

# %%
dict_df_northwind['suppliers'].toPandas().duplicated().sum()
# Out:
# Out[396]: 0

# %% [markdown]
# #### 2.3.11 Tabela "territories"

# %%
dict_df_northwind['territories'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>territory_id</th>
#       <th>territory_description</th>
#       <th>region_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1581</td>
#       <td>Westboro</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1730</td>
#       <td>Bedford</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1833</td>
#       <td>Georgetow</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2116</td>
#       <td>Boston</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2139</td>
#       <td>Cambridge</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['territories'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   territory_id           53 non-null     int32
#  1   territory_description  53 non-null     object
#  2   region_id              53 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 976.0+ bytes

# %%
dict_df_northwind['territories'].toPandas().duplicated().sum()
# Out:
# Out[399]: 0

# %% [markdown]
# #### 2.3.12 Tabela "us_states"

# %%
dict_df_northwind['us_states'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state_id</th>
#       <th>state_name</th>
#       <th>state_abbr</th>
#       <th>state_region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Alabama</td>
#       <td>AL</td>
#       <td>south</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Alaska</td>
#       <td>AK</td>
#       <td>north</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Arizona</td>
#       <td>AZ</td>
#       <td>west</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Arkansas</td>
#       <td>AR</td>
#       <td>south</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>California</td>
#       <td>CA</td>
#       <td>west</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict_df_northwind['us_states'].toPandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state_id      51 non-null     int32
#  1   state_name    51 non-null     object
#  2   state_abbr    51 non-null     object
#  3   state_region  51 non-null     object
# dtypes: int32(1), object(3)
# memory usage: 1.5+ KB

# %%
dict_df_northwind['us_states'].toPandas().duplicated().sum()
# Out:
# Out[402]: 0

# %% [markdown]
# ### 2.4 Transformando os dados

# %% [markdown]
# #### 2.4.1 Adicionando as colunas "order_year" e "order_month" no DF da tabela "orders"
# Essas colunas foram criadas com o intuito de usá-las para gerar tabelas agregadas no Data Lakehouse.

# %%
from pyspark.sql.functions import *

df_orders_processed = dict_df_northwind['orders'].select(
    'order_id',
    'customer_id',
    'employee_id',
    'order_date',
    year(dict_df_northwind['orders'].order_date).alias('order_year'),
    month(dict_df_northwind['orders'].order_date).alias('order_month'),
    'required_date',
    'shipped_date',
    'ship_via',
    'freight',
    'ship_name',
    'ship_address',
    'ship_city',
    'ship_region',
    'ship_postal_code',
    'ship_country')

# %%
display(df_orders_processed.toPandas().head())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>employee_id</th><th>order_date</th><th>order_year</th><th>order_month</th><th>required_date</th><th>shipped_date</th><th>ship_via</th><th>freight</th><th>ship_name</th><th>ship_address</th><th>ship_city</th><th>ship_region</th><th>ship_postal_code</th><th>ship_country</th></tr></thead><tbody><tr><td>10248</td><td>VINET</td><td>5</td><td>1996-07-04T00:00:00.000+0000</td><td>1996</td><td>7</td><td>1996-08-01T00:00:00.000+0000</td><td>1996-07-16</td><td>3</td><td>32.38</td><td>Vins et alcools Chevalier</td><td>59 rue de l'Abbaye</td><td>Reims</td><td>NULL</td><td>51100</td><td>France</td></tr><tr><td>10249</td><td>TOMSP</td><td>6</td><td>1996-07-05T00:00:00.000+0000</td><td>1996</td><td>7</td><td>1996-08-16T00:00:00.000+0000</td><td>1996-07-10</td><td>1</td><td>11.61</td><td>Toms Spezialitäten</td><td>Luisenstr. 48</td><td>Münster</td><td>NULL</td><td>44087</td><td>Germany</td></tr><tr><td>10250</td><td>HANAR</td><td>4</td><td>1996-07-08T00:00:00.000+0000</td><td>1996</td><td>7</td><td>1996-08-05T00:00:00.000+0000</td><td>1996-07-12</td><td>2</td><td>65.83</td><td>Hanari Carnes</td><td>Rua do Paço, 67</td><td>Rio de Janeiro</td><td>RJ</td><td>05454-876</td><td>Brazil</td></tr><tr><td>10251</td><td>VICTE</td><td>3</td><td>1996-07-08T00:00:00.000+0000</td><td>1996</td><td>7</td><td>1996-08-05T00:00:00.000+0000</td><td>1996-07-15</td><td>1</td><td>41.34</td><td>Victuailles en stock</td><td>2, rue du Commerce</td><td>Lyon</td><td>NULL</td><td>69004</td><td>France</td></tr><tr><td>10252</td><td>SUPRD</td><td>4</td><td>1996-07-09T00:00:00.000+0000</td><td>1996</td><td>7</td><td>1996-08-06T00:00:00.000+0000</td><td>1996-07-11</td><td>2</td><td>51.3</td><td>Suprêmes délices</td><td>Boulevard Tirou, 255</td><td>Charleroi</td><td>NULL</td><td>B-6000</td><td>Belgium</td></tr></tbody></table></div>

# %% [markdown]
# ### 2.5 Substituindo o DataFrame
# Substituindo "dict_df_northwind['orders']" por "df_orders_processed" no dicionário de DataFrames.
# Ou seja, substituindo o DF da tabela "orders" pelo DF processado com as novas colunas ("order_year" e "order_month").

# %%
dict_df_northwind.update({'orders': df_orders_processed})

# %%
# Visualizando o DF da tabela "orders" com as duas novas colunas ("order_year" e "order_month")
dict_df_northwind['orders'].toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>customer_id</th>
#       <th>employee_id</th>
#       <th>order_date</th>
#       <th>order_year</th>
#       <th>order_month</th>
#       <th>required_date</th>
#       <th>shipped_date</th>
#       <th>ship_via</th>
#       <th>freight</th>
#       <th>ship_name</th>
#       <th>ship_address</th>
#       <th>ship_city</th>
#       <th>ship_region</th>
#       <th>ship_postal_code</th>
#       <th>ship_country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10248</td>
#       <td>VINET</td>
#       <td>5</td>
#       <td>1996-07-04</td>
#       <td>1996</td>
#       <td>7</td>
#       <td>1996-08-01</td>
#       <td>1996-07-16</td>
#       <td>3</td>
#       <td>32.38</td>
#       <td>Vins et alcools Chevalier</td>
#       <td>59 rue de l'Abbaye</td>
#       <td>Reims</td>
#       <td>NULL</td>
#       <td>51100</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10249</td>
#       <td>TOMSP</td>
#       <td>6</td>
#       <td>1996-07-05</td>
#       <td>1996</td>
#       <td>7</td>
#       <td>1996-08-16</td>
#       <td>1996-07-10</td>
#       <td>1</td>
#       <td>11.61</td>
#       <td>Toms Spezialitäten</td>
#       <td>Luisenstr. 48</td>
#       <td>Münster</td>
#       <td>NULL</td>
#       <td>44087</td>
#       <td>Germany</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10250</td>
#       <td>HANAR</td>
#       <td>4</td>
#       <td>1996-07-08</td>
#       <td>1996</td>
#       <td>7</td>
#       <td>1996-08-05</td>
#       <td>1996-07-12</td>
#       <td>2</td>
#       <td>65.83</td>
#       <td>Hanari Carnes</td>
#       <td>Rua do Paço, 67</td>
#       <td>Rio de Janeiro</td>
#       <td>RJ</td>
#       <td>05454-876</td>
#       <td>Brazil</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10251</td>
#       <td>VICTE</td>
#       <td>3</td>
#       <td>1996-07-08</td>
#       <td>1996</td>
#       <td>7</td>
#       <td>1996-08-05</td>
#       <td>1996-07-15</td>
#       <td>1</td>
#       <td>41.34</td>
#       <td>Victuailles en stock</td>
#       <td>2, rue du Commerce</td>
#       <td>Lyon</td>
#       <td>NULL</td>
#       <td>69004</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10252</td>
#       <td>SUPRD</td>
#       <td>4</td>
#       <td>1996-07-09</td>
#       <td>1996</td>
#       <td>7</td>
#       <td>1996-08-06</td>
#       <td>1996-07-11</td>
#       <td>2</td>
#       <td>51.30</td>
#       <td>Suprêmes délices</td>
#       <td>Boulevard Tirou, 255</td>
#       <td>Charleroi</td>
#       <td>NULL</td>
#       <td>B-6000</td>
#       <td>Belgium</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2.6 Limpeza
# Removendo o diretório "trusted", caso este notebook seja executado mais de uma vez.

# %%
dbutils.fs.rm(northwind + 'trusted', recurse=True)
# Out:
# Out[407]: False

# %% [markdown]
# ### 2.7 Gravando os arquivos na camada "trusted"

# %%
for key, value in dict_df_northwind.items():
    value.write.mode("overwrite").format("parquet").save(northwind + f'trusted/{key}')

# %% [markdown]
# ### 2.8 Registrando as tabelas no Metastore

# %%
path_trusted = northwind + 'trusted/'

for folder in dbutils.fs.ls(path_trusted):
    folder_name = f'{folder.name}'.rsplit('/', 1)[0]
    spark.sql(
        f"""
        DROP TABLE IF EXISTS {folder_name}
        """
    )
    spark.sql(
        f"""
        CREATE TABLE {folder_name}
        USING PARQUET
        LOCATION "{northwind}trusted/{folder.name}"
        """
    )
    spark.sql(
        f"""
        REFRESH TABLE {folder_name}
        """
    )

# %% [markdown]
# ### 2.9 Verificando o número de registros na primeira tabela ("categories")

# %%
tb_trusted_categories = spark.read.table('categories')
tb_trusted_categories.count()
# Out:
# Out[410]: 8

# %% [markdown]
# ### 2.10 Exibindo os atributos da tabela "categories", criada na camada "trusted"

# %%
# %sql
DESCRIBE EXTENDED categories;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>category_id</td><td>int</td><td>null</td></tr><tr><td>category_name</td><td>string</td><td>null</td></tr><tr><td>description</td><td>string</td><td>null</td></tr><tr><td>picture</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>letscode_thais_trusted</td><td></td></tr><tr><td>Table</td><td>categories</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Tue May 17 08:38:26 UTC 2022</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.2.1</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>PARQUET</td><td></td></tr><tr><td>Location</td><td>dbfs:/letscode/thais/northwind/trusted/categories</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat</td><td></td></tr></tbody></table></div>
